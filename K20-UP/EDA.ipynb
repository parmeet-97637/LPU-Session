# %% [markdown]
# ## What is EDA?

# %% [markdown]
# 1. It is Exploratory Data Analysis
# 2. Drawing Insights form the given datasets.
# 3. Finding Patterns in your datasets.
# 4. Finding Anamolies in your datasets.

# %% [markdown]
# ## Sources of Data

# %% [markdown]
# 1. Public Data
#     1. Kaggle
#     2. GIT
#     3. Open source platforms
#     4. Social Media Platforms
#
# 2. Private Data
#     1. Organizations
#     2. Government Data

# %% [markdown]
# ## Types of Data

# %% [markdown]
# 1. Sturctured
#     1. Tabular Format (Rows & Cols), e.g., Excel, SQL Database
#
# 2. Unstructured
#     2. Videos, Photos
#
# 3. Semi-sturcutred
#     3. Emails, JSON,TXT, Wordfile, No SQL Database

# %% [markdown]
# ## Data Types

# %% [markdown]
# 1. Categorical
#         Examples : Computer Languages, Name, Colors, Vegetables,
# 2. Numerical
#         Examples : Salary, Roll no., age, ID
# 3. Date/Time

# %% [markdown]
# ### 1. Categorical Features : It represents grouping

# %% [markdown]
# ***A. Ordered Categorical Variable*** : Comparison is possible, Squence<br>
#     Example: Ratings, Month, Temperature(Hot/Cold), Height(small/Tall/Medium), Salary(High/Low/Medium)
#
# **B. Un-Orderd Categorical Variable** : No Sequence<br>
#     Example : Name, Gender, Courses, Loan(Personal/Home/Commercial)

# %% [markdown]
# #### 2. Numerical Features : (Quantitative Variables) : It sepecifies amounts

# %% [markdown]
# ***A. Discrete Features*** : Which can be counted, Measured (Any countable numerical integer feature)<br>
#     Example: Age(25,26), Rank, Year
#
# ***B. Continuous Features*** : any values (folat/decimal values)<br>
#     Example : Age(26.5,27.1), Height, Weight, marks, percentage

# %% [markdown]
# ## Categorical Features/Variables

# %% [markdown]
# **1. Binary Variable** : The variable that can take only 2 values<br>
#     Outcomes : Yes/No, Heads/Tails, Win/Loose
#
# **2. Nominal Variable** : Groups with no rank or order between them<br>
#     Example : Names, colors, courses, Brand Names
#
# **3. Ordinal Variable**:Groups that can be ranked or specified in a order<br>
#     Example : Ratings, Ranks

# %% [markdown]
# ## Analysis Steps

# %% [markdown]
# 1. **Univariate Analysis :**
#     - Working with 1 variable
#     - Analysing one variable at a time
#
#     **Segmented Univariate Analysis ** : 1numerical +1 categorical
# <br><br>
# 2. **Bi-variate Analysis :**
#     - working with 2 variables
#     - analysing 2 variables at a time
# <br><br>
# 3. **Multi-variate Analysis:**
#     - working with more than 2 variables

# %% [markdown]
# ## 1. Univariate Analysis

# %% [markdown]
# **A. Numerical Feature:** Scatterplot, lineplot, striplot, swarmplot, denisty plot, box plot<br>
# **B. categorical Features :** countplot,histograms, distplot,pie chart,

# %% [markdown]
# ## 2. Bivariate Analysis

# %%
Bins/Buckets : Historgram 

salary : 100.50,2000,500000 (continuous) -> convert to categorical ( I will create bins)

wwiths : 10,20,30,40,50,60,70,100,

10-20
20-30
40-50
60-70

# %% [markdown]
# **Categorical Analysis(including discrete variables)**<br>
#
# - **Frequency of the the two variables/categories**<br>
#     - Crosstab
#     - Heatmaps
#     - stacked bar charts
#
# - Range of continuous variables with respect to each category(Binning)<br>
#     - Boxplots
#     - Violin plots
#     - Swam plots
#     - count plots
#     - Bar plots

# %%
Gender and Salary

M : avg(salary)
F : avg(salary)

# %% [markdown]
# **Continuous Variables**
# - Range of continuous variables with respect to each category
#     - Boxplots
#     - Violin plots
#     - Swam plots
#     - count plots
#     - Bar plots
# - How the increase or decrease in one variable changes the other variable (2 Numerical features)
#     - line plot
#     - scatter plot

# %% [markdown]
# ## Demo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Source of Data : kaggle Data set(Public) : Titanic Data set

# %% [markdown]
# ### 1. Import Necessary Libraries

# %%
# Data Manipulation Libraries
import pandas as pd
import numpy as np

# Data Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# magic command to show the plot in jupyter 
# %matplotlib inline

# ignore the warnings
import warnings
warnings.filterwarnings('ignore')

#settings
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',None)

# %% [markdown]
# ### 2. Read the dataset

# %%
df = pd.read_csv("train.csv")
df.head() # read the first five rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 3. Undertsand the Data

# %%
# display the dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Ordinal Variable** : *PCLASSS* (The order is important and the numericla operation doesnot make any sense.)
#
# **Binary Variable** : *Survived*(It has 2 levels : 0 - Not survived, 1- survived), Sex(2 levels : Male & Female)
#
# **Nominal variable** : Name,Ticket, Cabin, Embarked
#
# **Discrete Numerical Feature** : SibSp, Parch
#
# **Continuous Numerical Feature** : Fare, Age

# %%
## let us check the descriptive statistics of the dataset
df.describe(percentiles=[.05,.25,.5,.75,.9,.95,.99]) # it will given the descriptive statistics of all numerical features by default
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 5%       45.500000    0.000000    1.000000    4.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# 90%     802.000000    1.000000    3.000000   50.000000    1.000000
# 95%     846.500000    1.000000    3.000000   56.000000    3.000000
# 99%     882.100000    1.000000    3.000000   65.870000    5.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 5%       0.000000    7.225000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# 90%      2.000000   77.958300
# 95%      2.000000  112.079150
# 99%      4.000000  249.006220
# max      6.000000  512.329200

# %% [markdown]
# **Assumptions:**
# 1. The children less than 2 years old are not charged
# 2. The highest Fare is 512.392 so it might be possible that the passengers are accompanied by their family and their is a combined ticket which is having this much fare. or, The passenger might be travelling in the first class.

# %%
df['PassengerId'].nunique()
# Out:
# 891

# %% [markdown]
# All the passeneger IDs are unique hence, this columns will not be useful for our analysis

# %%
df.describe(include='object') # descriptive statistics of all the categorical features
# Out:
#                             Name   Sex  Ticket Cabin Embarked
# count                        891   891     891   204      889
# unique                       891     2     681   147        3
# top     Olsen, Mr. Henry Margido  male  347082    G6        S
# freq                           1   577       7     4      644

# %% [markdown]
# **Assumptions:**
# 1. Thre is a family of 7 people who is travlleing on Ticke number *1601*

# %%
### check for the percentage of missing values
round((df.isnull().sum()/len(df))*100,2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %% [markdown]
# **Observations**
# 1. 20% of the ages are missing
# 2. Almost 78% of the cabin values are missing
# 3. Nearly 0.2% of th emarked values are missing

# %% [markdown]
# ## Analyse the Age Column

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#analyse the age on basis of Gender : Univariate Segmented Analysis
df.groupby('Sex')['Age'].mean().reset_index()
# Out:
#       Sex        Age
# 0  female  27.915709
# 1    male  30.726645

# %%
df.loc[df['Age'].isnull(),'Sex'].value_counts()
# Out:
# male      124
# female     53
# Name: Sex, dtype: int64

# %%
# avg age of male children, female children
# avg age of youngsters - male & female separately
# avg age of old people - male & feamle separatey
# we will find the count of age missing on basis of above parameters and thenimpute the values 
# Why are we doing this.? to minimze Bias(errors) in our dataset

# %%
# fill/impute the mising age
df.loc[(df['Age'].isnull()) & (df['Sex']=='male'),'Age'] = 31

# %%
df.loc[(df['Age'].isnull()) & (df['Sex']=='female'),'Age'] = 30

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## How many people Survived?

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(18,8)) # Created the blank figure with 2 axes

df['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct = '%1.2f%%',ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel("")
ax[0].legend()
sns.countplot('Survived',data=df,ax=ax[1])
ax[1].set_title('Survived')
plt.savefig("Survied.png")
plt.show()

# %% [markdown]
# **Observations :**
# - Majority of people didnot survived
# - Death Rate : 61.62%
# - Out of 891 passenegers only 342 people survived

# %% [markdown]
# # Analyse How the Survival Rate varies with repect to Gender

# %%
df.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
pd.crosstab(df.Sex,df.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_98808_row0_col0,#T_98808_row0_col2,#T_98808_row1_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_98808_row0_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_98808_row1_col0{
#             background-color:  #2c9666;
#             color:  #000000;
#         }#T_98808_row1_col2{
#             background-color:  #8bc566;
#             color:  #000000;
#         }#T_98808_row2_col0,#T_98808_row2_col1,#T_98808_row2_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_98808_" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_98808_level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_98808_row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_98808_row0_col1" class="data row0 col1" >233</td>
#                         <td id="T_98808_row0_col2" class="data row0 col2" >314</td>
#             </tr>
#             <tr>
#                         <th id="T_98808_level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_98808_row1_col0" class="data row1 col0" >468</td>
#                         <td id="T_98808_row1_col1" class="data row1 col1" >109</td>
#                         <td id="T_98808_row1_col2" class="data row1 col2" >577</td>
#             </tr>
#             <tr>
#                         <th id="T_98808_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_98808_row2_col0" class="data row2 col0" >549</td>
#                         <td id="T_98808_row2_col1" class="data row2 col1" >342</td>
#                         <td id="T_98808_row2_col2" class="data row2 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Observations**
# - Surival Rate of Females are more as compared to males
# - Male population is more than female

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
df[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=df, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.xticks
plt.savefig('Survival Ratio')
plt.show()

# %% [markdown]
# - Survival Rate for females is arounf 75% while the Survival rate for males is around 18-19%.
# - Though the number of males travelling in the ship is more still the number of females surival rate is twice that of males.

# %% [markdown]
# ## How my age and Fare are moving (Numerical-Numerical Analysis)
#  - Correlation plot
#  - Scatter plots
#  - joint plots
#  - pair plots

# %%
sns.scatterplot(x='Age',y='Fare', data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# # Heatmap for all numerical variables

# %%
# How the variables are correlated with each other
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033451 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.076226 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.325957  0.083081  0.018443
# Age             0.033451 -0.076226 -0.325957  1.000000 -0.233553 -0.183907
# SibSp          -0.057527 -0.035322  0.083081 -0.233553  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.183907  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.087768  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.087768
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# **Correlation is the statitical term decribing how the two features/variables moves with respect to each other**
# - Positive Correlation
# - Negative Correlation
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# $ r = \frac{\sum(x_i - \bar x) ((y_i - \bar y)}{\sqrt(\sum(x_i - \bar x)^2\sum(y_i - \bar y)^2}$

# %%
Age : 20,21,22
mean_age : 21
Heigth : 150,151,152
mean_height = 151

r = ((20-21)(150-151)+(21-21)(151-151)+(22-21)(152-151))/ sqrt( ((20-21)^2+(21-21)^2+(22-21)) * (((150-151)^2+(151-151)^2 +(152-151)^2))

# %%
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn', linewidths=0.2,annot_kws={'size':20})
fig =plt.gcf()
fig.set_size_inches(18,5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# **Observations**
# - Fare and PClass are negatively correlated
# - SibSP and PArch are positively correlated

# %% [markdown]
# **Limitation of Heatmap**
# - You cannot see the exact distribution of one variable wrt another variable

# %%
## Useful when you have few variables 
sns.pairplot(df,diag_kind='kde')

# %% [markdown]
# **Causation**
# - what is the cause of the relationship.
# - correlation doesnot imply causation.

# %% [markdown]
# # How my Survial Rates are varying wrt PClass

# %%
pd.crosstab(df.Pclass,df.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_dbd00_row0_col0,#T_dbd00_row1_col1,#T_dbd00_row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_dbd00_row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_dbd00_row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_dbd00_row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_dbd00_row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_dbd00_row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_dbd00_row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_dbd00_row3_col0,#T_dbd00_row3_col1,#T_dbd00_row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_dbd00_" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dbd00_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_dbd00_row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_dbd00_row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_dbd00_row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_dbd00_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_dbd00_row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_dbd00_row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_dbd00_row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_dbd00_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_dbd00_row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_dbd00_row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_dbd00_row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_dbd00_level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_dbd00_row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_dbd00_row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_dbd00_row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Observations**
# - If the passenger is travelling in 1st Class more chances of Surival Rate(63% Survival Rate)
# - Passengers travelling in third class are given less priority and hence their surival rates are very low

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
df['Pclass'].value_counts().plot.bar(color=['#CD7F32','red','g'],ax=ax[0])
ax[0].set_title('Numer of Passengers by Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=df, ax=ax[1])
ax[1].set_title('Pclass : Survived Vs Dead')
plt.savefig("Survival Ratio Vs Pclass.png")
plt.show()

# %% [markdown]
# **Numerical-Categorical Analysis**
# - Pivot_table, cross tab, group-by
# - Box Plots
#
#
# **Numerical_NUmerical Analysis**
# - Scatterplot
# - Heatmaps(correlation)
# - Pairplot
#
# **Categorical_categorical Analysis**
# - counts, mean, median (metrics) using groupby
# - bar plots
# - stacked plots /side by plots
